# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (677 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.1/677.1 kB 7.3 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 33.6 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.4.2 pymongo-4.6.1

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
uri = "mongodb+srv://selecto:DmdSvpAnRnudk1Zj@reviews-list.q56a6p2.mongodb.net/?retryWrites=true&w=majority"
client = MongoClient(uri, server_api=ServerApi('1'))
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client['Reviews']  # Replace 'your_database' with your database name

# List collections within the database
collection_names = db.list_collection_names()

# Display the collection names
print("Collections in the database:")
for name in collection_names:
    print(name)
# Out:
# Collections in the database:
# Apple watch SE 2
# helo

# %%
db = client['Reviews']
collection = db['Apple watch SE 2']

# Retrieve the first 20 documents from the collection
cursor = collection.find().limit(20)

# Display the fetched documents
for document in cursor:
    print(document)
# Out:
# {'_id': ObjectId('657975d51935ff9a4d9dc6ac'), 'Product Name': 'Apple Watch SE GPS 40mm Silver Aluminum Case with Storm Blue Sport Band - S/M with AppleCare+ (2 Years)'}
# {'_id': ObjectId('657975d81935ff9a4d9dc6ad'), 'Review': "The Apple Watch SE (2nd Generation) [GPS 40mm] with a Silver Aluminum Case and Storm Blue Sport Band is a popular option in Apple's smartwatch lineup. Here's a brief review focusing on its features and potential limitations:\n\nPros:\nDesign and Aesthetics: The silver aluminum case paired with the storm blue sport band offers a sleek and modern look, appealing to a wide range of users. The design is both stylish and functional.\n\nPerformance: As a 2nd generation model, it boasts improved performance over its predecessor, with faster and more efficient processing capabilities.\n\nHealth and Fitness Tracking: The watch excels in health and fitness tracking, offering a variety of features like heart rate monitoring, step counting, and workout tracking, making it ideal for fitness enthusiasts.\n\nUser Interface and Experience: The watchOS provides an intuitive and user-friendly interface, with easy navigation and access to a wide range of apps and functionalities.\n\nBattery Life: It offers a decent battery life for a smartwatch, sufficient for daily use without frequent recharging.\n\nCons:\nPrice: While more affordable than some other models in the Apple Watch series, it still carries a relatively high price tag, which might be a consideration for budget-conscious buyers.\n\nLimited Compatibility: Best suited for users already within the Apple ecosystem, as some features might not be fully available or optimized when paired with non-Apple devices.\n\nNo Always-On Display: Unlike the higher-end models, the SE does not feature an always-on display, which means the screen goes dark when not in use.\n\nHealth Features: While it has robust health tracking, it lacks some of the advanced health features found in the more expensive Apple Watch models, such as blood oxygen monitoring and ECG.\n\nIn summary, the Apple Watch SE (2nd Gen) [GPS 40mm] with a Silver Aluminum Case and Storm Blue Sport Band is a stylish and capable smartwatch, offering a balanced mix of features and performance. It's an excellent choice for those who prioritize health and fitness tracking, seamless integration with the Apple ecosystem, and a modern design. However, its price, compatibility limitations with non-Apple products, and the absence of some advanced health features are factors to consider."}
# {'_id': ObjectId('657975d81935ff9a4d9dc6ae'), 'Review': 'I am loving this watch, I’m so glad I went with this one and saved the money I would have spent get the EKG included in the series 8 or 9. My cardiologist said it’s not reliable anyways, so I’m glad I asked her first.\nPros- It is very fast and hasn’t missed a call or notification yet.\nThere are tons of features included as well that I love!\nAlso, for those people missing the group challenges that Fitbit got rid of, Apple Watches have group challenges 🙌🏼 my whole family was missing those and once I told them the Apple Watches have groups and other fun things like the walkie talkie feature lol, they all ordered one too!!\nNegative- I will say that the battery life on these do not compare to the Fitbit watches. My Sense battery lasted 3 days! This watch barely lasts 24 hours 😭\nAnd it’s even harder to track my sleep since I end up having to plug it in so it’s ready to go when I wake up.\n\nTLDR- love it so much my whole family ordered them too lol. The battery is disappointing compared to Fitbit. But still worth it!! 4.5 ⭐️'}
# {'_id': ObjectId('657975d81935ff9a4d9dc6af'), 'Review': 'I use it to track my activity and steps, but also for notifications. I used to use a fossil smart watch, which I think had better features on it, such as being able to choose which google accounts i would get notifications from, the watch faces had more variety in having all the information that mattered to me available on the Home Screen, etc. I know this has a lot more features and such that I haven’t figured out yet, and at the end of the day it does the job. What I really like is the lightweight nature of it. It was a night and day difference when I switched watches. I don’t even feel it on my wrist most of the time, which allows me to sleep with it comfortably, which I never did before with the fossil watch. So it’s nice that I now get to experience the benefits of sleep tracking. I like that the wake feature always works, which has not been my experience in the past. The charge for me last one day, which is fine. I just charge it a bit before I go to bed and a bit in the morning when I get ready, and I haven’t had many issues.'}
# {'_id': ObjectId('657975d91935ff9a4d9dc6b0'), 'Review': 'I recently acquired the Apple Watch SE (2nd Gen) with the Starlight Aluminum Case and Starlight Sport Band, and I must say it has been a game-changer for me. As a graduate student pursuing a master\'s in computer science at the University of Florida and a research assistant at the Learn Dialogue Lab, I needed a smartwatch that could seamlessly integrate into my active lifestyle, help me stay on top of my health, and even assist in my research tasks. The Apple Watch SE has exceeded my expectations in all these aspects.\n\nOne of the standout features for me is the fitness and sleep tracking capabilities. With my busy schedule, it\'s crucial to keep tabs on my physical activity and sleep patterns. The Apple Watch SE does an excellent job of tracking my steps, calories burned, and even encourages me to move when I\'ve been sitting for too long. The sleep tracking feature has been a revelation, providing insights into the quality of my sleep and helping me make adjustments for better rest.\n\nBeing a tech enthusiast and someone deeply involved in the IT sector, I appreciate the crash detection and heart rate monitoring functions. Safety is paramount, and the watch\'s ability to detect a potential fall and initiate an emergency call is a reassuring feature, especially when I\'m out traveling or in the middle of a research project. The heart rate monitor keeps me informed about my cardiovascular health during workouts and daily activities.\n\nAs someone who loves teaching and mentoring, the Apple Watch SE also helps me manage my busy schedule. The calendar notifications and reminders keep me on track for meetings with my mentees and colleagues at the lab, which is essential for our collaborative projects, such as "Collaborative sports," "Amby: Language model for middle schoolers," and "Integrate AI."\n\nMoreover, the watch seamlessly integrates with my iPhone, allowing me to respond to messages, emails, and calls without taking out my phone, which is incredibly convenient during our frequent lab meetings and while I\'m on the go.\n\nIn conclusion, the Apple Watch SE (2nd Gen) has become an indispensable part of my daily life. Its fitness and health-tracking features, coupled with its integration into my professional and academic activities, make it a must-have for anyone in the IT sector aiming to be a leader in future IT solutions. Whether I\'m teaching React JS or exploring new states in the USA, this smartwatch has proven to be a reliable companion. Highly recommended!'}
# {'_id': ObjectId('657975d91935ff9a4d9dc6b1'), 'Review': 'It took me forever to realize I needed this in my life. I spend less time on my phone now, and when I leave my phone somewhere in the house, I can find it now. Lol. I don’t miss calls or messages now. Most importantly tho, I spend less time on the phone. That alone is almost the too high $200 price tag. The band, selected the loop, is awful. Ugly and so bulky. Immediately purchased a non Apple slim braided stretchy loop and I love it. I’ve tried a few (silicone, metal magnetic, etc) and so far it’s the only one I like (small wrists). I also purchased a clear cover and privacy screen for extra protection. I haven’t worn a watch in years, so it takes a little getting used to again - and not whacking it on the desk! So far so good!\n\nOne gripe. The lack of actual Apple Watch faces. What gives? I hate giving third-party apps control of everything! And even bands. Talk about ugly. Where’s all the fun trademarked ones? These have been around long enough now, cmon Apple! I can deal with the lack of complications (why are they so inconsistent? And why can’t we not add Siri to anything but the Siri face?), but faces and bands??'}
# {'_id': ObjectId('657975d91935ff9a4d9dc6b2'), 'Review': 'Nice watch! I’ve had a few apple watches before and bought this one to replace my series 6 which cracked. This one was way cheaper than what I spend on my series 6 when it first came out which is nice! But it doesn’t come with all the new features, which is expected for a cheaper version. Still overall a great purchase and a great deal.'}
# {'_id': ObjectId('657975d91935ff9a4d9dc6b3'), 'Review': 'This product came perfect no scratches or nothing. It look brand new. If you have a iPhone X or later this watch is not for you. The battery life is good but you do have to charge it every day if you don’t the battery will only last for 3-4 hours the next day.'}
# {'_id': ObjectId('657975da1935ff9a4d9dc6b4'), 'Review': '!00% worth it. Bought it during black friday sale and is work every dime. I am able to pick /accept calls and decline right from my wrist , and thats the mind-blowing feature. The screen quality and resolution is super bright and LED quality. All clock features, fitness tracking, GPS tracking makes it a one in all tool'}
# {'_id': ObjectId('657975da1935ff9a4d9dc6b5'), 'Review': "So I originally had an Apple Watch 3 series for as far back as I can remember. There is nothing wrong with it, I just decided to hand it down to my 11yr old and get myself an upgrade. There were a few new features, but I wouldn't say the battery life has improved much if at all. Not a problem for me as I just charge it overnight. All in all, I love this Apple watch just as much as my last one and will continue to buy their products."}
# {'_id': ObjectId('657975da1935ff9a4d9dc6b6'), 'Review': 'I’ve had a couple Apple Watches in the last- first and third gen. I was ready to upgrade my third gen since it was slowing down and boy, this is a huge upgrade! It’s much faster and works seamlessly with my phone. I couldn’t be happier with my purchase!'}
# {'_id': ObjectId('657975db1935ff9a4d9dc6b7'), 'Review': 'I bought this as a birthday present to replace a much older version. It may not have some of the features of other models but it works much smoother and faster than the older models and does exactly what she needs it to do. Definitely happy I didn’t spend more for functions she wouldn’t use'}
# {'_id': ObjectId('657975dc1935ff9a4d9dc6b8'), 'Review': "Bought this watch as a gift for my daughter. It's exactly whats described. Nice size watch. I bought the basic band but you can purchase different style bands. Links to phone with no problem."}
# {'_id': ObjectId('657975dc1935ff9a4d9dc6b9'), 'Review': 'After reading the reviews I wasn’t sure what to expect as this my first Apple Watch. So I gave it a couple of days and definitely a fan. Definitely recommend to anyone to purchase'}
# {'_id': ObjectId('657975dc1935ff9a4d9dc6ba'), 'Review': 'Works well as you would expect from an apple product. No issued with synching. Wish there was a way to increase the font for step counting. Has great features like if someone elderly falls you can have it contact your listed emergency contact.'}
# {'_id': ObjectId('657975dd1935ff9a4d9dc6bb'), 'Review': 'This is my first Apple Watch I have been using. I purchased this at the Black Friday deal of $179. The features are great. I recommend springing for a newer series. I am satisfied!'}
# {'_id': ObjectId('657975dd1935ff9a4d9dc6bc'), 'Review': 'it is great but it doesn’t come with a box charger, just the cord, which is annoying when i have to charge my phone and my watch.'}
# {'_id': ObjectId('657975dd1935ff9a4d9dc6bd'), 'Review': "When Apple introduced the Watch SE lineup, it was hailed as a budget-friendly alternative to its premium series, catering to users who wanted the core Apple Watch experience without the steep price. With the 2nd Gen Apple Watch SE, the brand has refined an impressive product. I recently gifted this to my daughter as a replacement for her older Apple Watch, and her joy was palpable.\n\nThe most noticeable improvement is its sleeker design. While it retains the iconic Apple Watch look, there's an undeniable modern refinement to it. This seamless integration of the case and band is more than just aesthetically pleasing and functional. In terms of performance, the updated processor offers quicker responses and smoother command executions. Apps launch with increased speed, and transitions are more fluid, providing a notably enhanced user experience.\n\nSoftware-wise, Apple's updates have made a marked difference. The introduction of new watch faces, expanded health tracking features, and improved notifications show that the company has actively considered user feedback. Another improvement, albeit a minor one, is the battery life. My daughter charges it less frequently than her previous Apple Watch, which is always a bonus.\n\nPairing the watch with her iPhone was straightforward, and its compatibility with all her apps stands out, emphasizing the smooth interoperability Apple is known for. In terms of value for money, the Watch SE (2nd Gen) hits the mark given its features and the improvements over its predecessor.\n\nIn conclusion, whether you're contemplating an upgrade from an older model or considering it as a gift for a loved one, the Apple Watch SE (2nd Gen) is a stellar choice. It exemplifies Apple's dedication to quality, innovation, and user satisfaction. My daughter's sheer delight with her new watch speaks volumes about its capabilities and charm. I highly recommend it!"}
# {'_id': ObjectId('657975dd1935ff9a4d9dc6be'), 'Review': 'Muy satisfecha con mi Apple Watch, es una buena inversión, tiene lo que necesito y se adaptó muy rápido a mi estilo de vida. Buena inversión.'}
# {'_id': ObjectId('657975de1935ff9a4d9dc6bf'), 'Review': 'I took one star off for the band. As someone else noted, the starlight band looks dirty. The watch itself works well.'}

# %%
# Retrieve the data from the collection
data = list(collection.find())

# Create a DataFrame for tabular representation
df = pd.DataFrame(data)

# Display the data in a table
df.head()
# Out:
#                         _id  \
# 0  657975d51935ff9a4d9dc6ac
# 1  657975d81935ff9a4d9dc6ad
# 2  657975d81935ff9a4d9dc6ae
# 3  657975d81935ff9a4d9dc6af
# 4  657975d91935ff9a4d9dc6b0
#
#                                         Product Name  \
# 0  Apple Watch SE GPS 40mm Silver Aluminum Case w...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               Review
# 0                                                NaN
# 1  The Apple Watch SE (2nd Generation) [GPS 40mm]...
# 2  I am loving this watch, I’m so glad I went wit...
# 3  I use it to track my activity and steps, but a...
# 4  I recently acquired the Apple Watch SE (2nd Ge...

# %%
# Out:
# Index(['_id', 'Product Name', 'Review'], dtype='object')
# 21
#                         _id  \
# 0  657975d51935ff9a4d9dc6ac
# 1  657975d81935ff9a4d9dc6ad
# 2  657975d81935ff9a4d9dc6ae
# 3  657975d81935ff9a4d9dc6af
# 4  657975d91935ff9a4d9dc6b0
#
#                                         Product Name  \
# 0  Apple Watch SE GPS 40mm Silver Aluminum Case w...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               Review
# 0                                                NaN
# 1  The Apple Watch SE (2nd Generation) [GPS 40mm]...
# 2  I am loving this watch, I’m so glad I went wit...
# 3  I use it to track my activity and steps, but a...
# 4  I recently acquired the Apple Watch SE (2nd Ge...

# %%
example = df['Review'][2]
print(example)
# Out:
# I am loving this watch, I’m so glad I went with this one and saved the money I would have spent get the EKG included in the series 8 or 9. My cardiologist said it’s not reliable anyways, so I’m glad I asked her first.
# Pros- It is very fast and hasn’t missed a call or notification yet.
# There are tons of features included as well that I love!
# Also, for those people missing the group challenges that Fitbit got rid of, Apple Watches have group challenges 🙌🏼 my whole family was missing those and once I told them the Apple Watches have groups and other fun things like the walkie talkie feature lol, they all ordered one too!!
# Negative- I will say that the battery life on these do not compare to the Fitbit watches. My Sense battery lasted 3 days! This watch barely lasts 24 hours 😭
# And it’s even harder to track my sleep since I end up having to plug it in so it’s ready to go when I wake up.
#
# TLDR- love it so much my whole family ordered them too lol. The battery is disappointing compared to Fitbit. But still worth it!! 4.5 ⭐️

# %%
tokens=nltk.word_tokenize(example)
tokens[:100000]
# Out:
# ['I',
#  'am',
#  'loving',
#  'this',
#  'watch',
#  ',',
#  'I',
#  '’',
#  'm',
#  'so',
#  'glad',
#  'I',
#  'went',
#  'with',
#  'this',
#  'one',
#  'and',
#  'saved',
#  'the',
#  'money',
#  'I',
#  'would',
#  'have',
#  'spent',
#  'get',
#  'the',
#  'EKG',
#  'included',
#  'in',
#  'the',
#  'series',
#  '8',
#  'or',
#  '9',
#  '.',
#  'My',
#  'cardiologist',
#  'said',
#  'it',
#  '’',
#  's',
#  'not',
#  'reliable',
#  'anyways',
#  ',',
#  'so',
#  'I',
#  '’',
#  'm',
#  'glad',
#  'I',
#  'asked',
#  'her',
#  'first',
#  '.',
#  'Pros-',
#  'It',
#  'is',
#  'very',
#  'fast',
#  'and',
#  'hasn',
#  '’',
#  't',
#  'missed',
#  'a',
#  'call',
#  'or',
#  'notification',
#  'yet',
#  '.',
#  'There',
#  'are',
#  'tons',
#  'of',
#  'features',
#  'included',
#  'as',
#  'well',
#  'that',
#  'I',
#  'love',
#  '!',
#  'Also',
#  ',',
#  'for',
#  'those',
#  'people',
#  'missing',
#  'the',
#  'group',
#  'challenges',
#  'that',
#  'Fitbit',
#  'got',
#  'rid',
#  'of',
#  ',',
#  'Apple',
#  'Watches',
#  'have',
#  'group',
#  'challenges',
#  '🙌🏼',
#  'my',
#  'whole',
#  'family',
#  'was',
#  'missing',
#  'those',
#  'and',
#  'once',
#  'I',
#  'told',
#  'them',
#  'the',
#  'Apple',
#  'Watches',
#  'have',
#  'groups',
#  'and',
#  'other',
#  'fun',
#  'things',
#  'like',
#  'the',
#  'walkie',
#  'talkie',
#  'feature',
#  'lol',
#  ',',
#  'they',
#  'all',
#  'ordered',
#  'one',
#  'too',
#  '!',
#  '!',
#  'Negative-',
#  'I',
#  'will',
#  'say',
#  'that',
#  'the',
#  'battery',
#  'life',
#  'on',
#  'these',
#  'do',
#  'not',
#  'compare',
#  'to',
#  'the',
#  'Fitbit',
#  'watches',
#  '.',
#  'My',
#  'Sense',
#  'battery',
#  'lasted',
#  '3',
#  'days',
#  '!',
#  'This',
#  'watch',
#  'barely',
#  'lasts',
#  '24',
#  'hours',
#  '😭',
#  'And',
#  'it',
#  '’',
#  's',
#  'even',
#  'harder',
#  'to',
#  'track',
#  'my',
#  'sleep',
#  'since',
#  'I',
#  'end',
#  'up',
#  'having',
#  'to',
#  'plug',
#  'it',
#  'in',
#  'so',
#  'it',
#  '’',
#  's',
#  'ready',
#  'to',
#  'go',
#  'when',
#  'I',
#  'wake',
#  'up',
#  '.',
#  'TLDR-',
#  'love',
#  'it',
#  'so',
#  'much',
#  'my',
#  'whole',
#  'family',
#  'ordered',
#  'them',
#  'too',
#  'lol',
#  '.',
#  'The',
#  'battery',
#  'is',
#  'disappointing',
#  'compared',
#  'to',
#  'Fitbit',
#  '.',
#  'But',
#  'still',
#  'worth',
#  'it',
#  '!',
#  '!',
#  '4.5',
#  '⭐️']

# %%
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
tagged = nltk.pos_tag(tokens)
tagged [:100000]
# Out:
# [('I', 'PRP'),
#  ('am', 'VBP'),
#  ('loving', 'VBG'),
#  ('this', 'DT'),
#  ('watch', 'NN'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('’', 'VBP'),
#  ('m', 'NNS'),
#  ('so', 'RB'),
#  ('glad', 'JJ'),
#  ('I', 'PRP'),
#  ('went', 'VBD'),
#  ('with', 'IN'),
#  ('this', 'DT'),
#  ('one', 'CD'),
#  ('and', 'CC'),
#  ('saved', 'VBD'),
#  ('the', 'DT'),
#  ('money', 'NN'),
#  ('I', 'PRP'),
#  ('would', 'MD'),
#  ('have', 'VB'),
#  ('spent', 'VBN'),
#  ('get', 'VB'),
#  ('the', 'DT'),
#  ('EKG', 'NNP'),
#  ('included', 'VBD'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('series', 'NN'),
#  ('8', 'CD'),
#  ('or', 'CC'),
#  ('9', 'CD'),
#  ('.', '.'),
#  ('My', 'PRP$'),
#  ('cardiologist', 'NN'),
#  ('said', 'VBD'),
#  ('it', 'PRP'),
#  ('’', 'NNP'),
#  ('s', 'VBZ'),
#  ('not', 'RB'),
#  ('reliable', 'JJ'),
#  ('anyways', 'NNS'),
#  (',', ','),
#  ('so', 'IN'),
#  ('I', 'PRP'),
#  ('’', 'VBP'),
#  ('m', 'JJ'),
#  ('glad', 'NN'),
#  ('I', 'PRP'),
#  ('asked', 'VBD'),
#  ('her', 'PRP'),
#  ('first', 'RB'),
#  ('.', '.'),
#  ('Pros-', 'VB'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('very', 'RB'),
#  ('fast', 'RB'),
#  ('and', 'CC'),
#  ('hasn', 'VB'),
#  ('’', 'NNP'),
#  ('t', 'NN'),
#  ('missed', 'VBD'),
#  ('a', 'DT'),
#  ('call', 'NN'),
#  ('or', 'CC'),
#  ('notification', 'NN'),
#  ('yet', 'RB'),
#  ('.', '.'),
#  ('There', 'EX'),
#  ('are', 'VBP'),
#  ('tons', 'NNS'),
#  ('of', 'IN'),
#  ('features', 'NNS'),
#  ('included', 'VBN'),
#  ('as', 'RB'),
#  ('well', 'RB'),
#  ('that', 'IN'),
#  ('I', 'PRP'),
#  ('love', 'VBP'),
#  ('!', '.'),
#  ('Also', 'RB'),
#  (',', ','),
#  ('for', 'IN'),
#  ('those', 'DT'),
#  ('people', 'NNS'),
#  ('missing', 'VBG'),
#  ('the', 'DT'),
#  ('group', 'NN'),
#  ('challenges', 'VBZ'),
#  ('that', 'IN'),
#  ('Fitbit', 'NNP'),
#  ('got', 'VBD'),
#  ('rid', 'JJ'),
#  ('of', 'IN'),
#  (',', ','),
#  ('Apple', 'NNP'),
#  ('Watches', 'NNP'),
#  ('have', 'VBP'),
#  ('group', 'NN'),
#  ('challenges', 'NNS'),
#  ('🙌🏼', 'VBP'),
#  ('my', 'PRP$'),
#  ('whole', 'JJ'),
#  ('family', 'NN'),
#  ('was', 'VBD'),
#  ('missing', 'VBG'),
#  ('those', 'DT'),
#  ('and', 'CC'),
#  ('once', 'RB'),
#  ('I', 'PRP'),
#  ('told', 'VBD'),
#  ('them', 'PRP'),
#  ('the', 'DT'),
#  ('Apple', 'NNP'),
#  ('Watches', 'NNP'),
#  ('have', 'VBP'),
#  ('groups', 'NNS'),
#  ('and', 'CC'),
#  ('other', 'JJ'),
#  ('fun', 'JJ'),
#  ('things', 'NNS'),
#  ('like', 'IN'),
#  ('the', 'DT'),
#  ('walkie', 'NN'),
#  ('talkie', 'NN'),
#  ('feature', 'NN'),
#  ('lol', 'NN'),
#  (',', ','),
#  ('they', 'PRP'),
#  ('all', 'DT'),
#  ('ordered', 'VBD'),
#  ('one', 'CD'),
#  ('too', 'RB'),
#  ('!', '.'),
#  ('!', '.'),
#  ('Negative-', 'JJ'),
#  ('I', 'PRP'),
#  ('will', 'MD'),
#  ('say', 'VB'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('battery', 'NN'),
#  ('life', 'NN'),
#  ('on', 'IN'),
#  ('these', 'DT'),
#  ('do', 'VBP'),
#  ('not', 'RB'),
#  ('compare', 'VB'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('Fitbit', 'NNP'),
#  ('watches', 'NNS'),
#  ('.', '.'),
#  ('My', 'PRP$'),
#  ('Sense', 'NN'),
#  ('battery', 'NN'),
#  ('lasted', 'VBD'),
#  ('3', 'CD'),
#  ('days', 'NNS'),
#  ('!', '.'),
#  ('This', 'DT'),
#  ('watch', 'NN'),
#  ('barely', 'RB'),
#  ('lasts', 'VBZ'),
#  ('24', 'CD'),
#  ('hours', 'NNS'),
#  ('😭', 'CD'),
#  ('And', 'CC'),
#  ('it', 'PRP'),
#  ('’', 'VBZ'),
#  ('s', 'JJ'),
#  ('even', 'RB'),
#  ('harder', 'RBR'),
#  ('to', 'TO'),
#  ('track', 'VB'),
#  ('my', 'PRP$'),
#  ('sleep', 'NN'),
#  ('since', 'IN'),
#  ('I', 'PRP'),
#  ('end', 'VBP'),
#  ('up', 'RB'),
#  ('having', 'VBG'),
#  ('to', 'TO'),
#  ('plug', 'VB'),
#  ('it', 'PRP'),
#  ('in', 'IN'),
#  ('so', 'IN'),
#  ('it', 'PRP'),
#  ('’', 'VBZ'),
#  ('s', 'JJ'),
#  ('ready', 'JJ'),
#  ('to', 'TO'),
#  ('go', 'VB'),
#  ('when', 'WRB'),
#  ('I', 'PRP'),
#  ('wake', 'VBP'),
#  ('up', 'RP'),
#  ('.', '.'),
#  ('TLDR-', 'JJ'),
#  ('love', 'NN'),
#  ('it', 'PRP'),
#  ('so', 'RB'),
#  ('much', 'JJ'),
#  ('my', 'PRP$'),
#  ('whole', 'JJ'),
#  ('family', 'NN'),
#  ('ordered', 'VBD'),
#  ('them', 'PRP'),
#  ('too', 'RB'),
#  ('lol', 'RB'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('battery', 'NN'),
#  ('is', 'VBZ'),
#  ('disappointing', 'JJ'),
#  ('compared', 'VBN'),
#  ('to', 'TO'),
#  ('Fitbit', 'NNP'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('still', 'RB'),
#  ('worth', 'IN'),
#  ('it', 'PRP'),
#  ('!', '.'),
#  ('!', '.'),
#  ('4.5', 'CD'),
#  ('⭐️', 'NN')]

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint()
# Out:
# (S
#   I/PRP
#   am/VBP
#   loving/VBG
#   this/DT
#   watch/NN
#   ,/,
#   I/PRP
#   ’/VBP
#   m/NNS
#   so/RB
#   glad/JJ
#   I/PRP
#   went/VBD
#   with/IN
#   this/DT
#   one/CD
#   and/CC
#   saved/VBD
#   the/DT
#   money/NN
#   I/PRP
#   would/MD
#   have/VB
#   spent/VBN
#   get/VB
#   the/DT
#   (ORGANIZATION EKG/NNP)
#   included/VBD
#   in/IN
#   the/DT
#   series/NN
#   8/CD
#   or/CC
#   9/CD
#   ./.
#   My/PRP$
#   cardiologist/NN
#   said/VBD
#   it/PRP
#   ’/NNP
#   s/VBZ
#   not/RB
#   reliable/JJ
#   anyways/NNS
#   ,/,
#   so/IN
#   I/PRP
#   ’/VBP
#   m/JJ
#   glad/NN
#   I/PRP
#   asked/VBD
#   her/PRP
#   first/RB
#   ./.
#   Pros-/VB
#   It/PRP
#   is/VBZ
#   very/RB
#   fast/RB
#   and/CC
#   hasn/VB
#   ’/NNP
#   t/NN
#   missed/VBD
#   a/DT
#   call/NN
#   or/CC
#   notification/NN
#   yet/RB
#   ./.
#   There/EX
#   are/VBP
#   tons/NNS
#   of/IN
#   features/NNS
#   included/VBN
#   as/RB
#   well/RB
#   that/IN
#   I/PRP
#   love/VBP
#   !/.
#   Also/RB
#   ,/,
#   for/IN
#   those/DT
#   people/NNS
#   missing/VBG
#   the/DT
#   group/NN
#   challenges/VBZ
#   that/IN
#   (PERSON Fitbit/NNP)
#   got/VBD
#   rid/JJ
#   of/IN
#   ,/,
#   (PERSON Apple/NNP Watches/NNP)
#   have/VBP
#   group/NN
#   challenges/NNS
#   🙌🏼/VBP
#   my/PRP$
#   whole/JJ
#   family/NN
#   was/VBD
#   missing/VBG
#   those/DT
#   and/CC
#   once/RB
#   I/PRP
#   told/VBD
#   them/PRP
#   the/DT
#   (ORGANIZATION Apple/NNP Watches/NNP)
#   have/VBP
#   groups/NNS
#   and/CC
#   other/JJ
#   fun/JJ
#   things/NNS
#   like/IN
#   the/DT
#   walkie/NN
#   talkie/NN
#   feature/NN
#   lol/NN
#   ,/,
#   they/PRP
#   all/DT
#   ordered/VBD
#   one/CD
#   too/RB
#   !/.
#   !/.
#   Negative-/JJ
#   I/PRP
#   will/MD
#   say/VB
#   that/IN
#   the/DT
#   battery/NN
#   life/NN
#   on/IN
#   these/DT
#   do/VBP
#   not/RB
#   compare/VB
#   to/TO
#   the/DT
#   (ORGANIZATION Fitbit/NNP)
#   watches/NNS
#   ./.
#   My/PRP$
#   Sense/NN
#   battery/NN
#   lasted/VBD
#   3/CD
#   days/NNS
#   !/.
#   This/DT
#   watch/NN
#   barely/RB
#   lasts/VBZ
#   24/CD
#   hours/NNS
#   😭/CD
#   And/CC
#   it/PRP
#   ’/VBZ
#   s/JJ
#   even/RB
#   harder/RBR
#   to/TO
#   track/VB
#   my/PRP$
#   sleep/NN
#   since/IN
#   I/PRP
#   end/VBP
#   up/RB
#   having/VBG
#   to/TO
#   plug/VB
#   it/PRP
#   in/IN
#   so/IN
#   it/PRP
#   ’/VBZ
#   s/JJ
#   ready/JJ
#   to/TO
#   go/VB
#   when/WRB
#   I/PRP
#   wake/VBP
#   up/RP
#   ./.
#   TLDR-/JJ
#   love/NN
#   it/PRP
#   so/RB
#   much/JJ
#   my/PRP$
#   whole/JJ
#   family/NN
#   ordered/VBD
#   them/PRP
#   too/RB
#   lol/RB
#   ./.
#   The/DT
#   battery/NN
#   is/VBZ
#   disappointing/JJ
#   compared/VBN
#   to/TO
#   (GPE Fitbit/NNP)
#   ./.
#   But/CC
#   still/RB
#   worth/IN
#   it/PRP
#   !/.
#   !/.
#   4.5/CD
#   ⭐️/NN)

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm
sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores('I am so happy!')
# Out:
# {'neg': 0.0, 'neu': 0.318, 'pos': 0.682, 'compound': 0.6468}

# %%
sia.polarity_scores(example)
# Out:
# {'neg': 0.045, 'neu': 0.804, 'pos': 0.151, 'compound': 0.9526}

# %%
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row['Review']
    myid = row['_id']

    # Check if the 'text' variable is a string
    if isinstance(text, str):
        res[myid] = sia.polarity_scores(text)
    else:
        # Handle other data types (e.g., float) as needed
        print(f"Skipping row with non-string data at index {i}")

# Print the results
print(res)
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]
# Skipping row with non-string data at index 0
# {ObjectId('657975d81935ff9a4d9dc6ad'): {'neg': 0.011, 'neu': 0.849, 'pos': 0.14, 'compound': 0.9924}, ObjectId('657975d81935ff9a4d9dc6ae'): {'neg': 0.045, 'neu': 0.804, 'pos': 0.151, 'compound': 0.9526}, ObjectId('657975d81935ff9a4d9dc6af'): {'neg': 0.0, 'neu': 0.851, 'pos': 0.149, 'compound': 0.9854}, ObjectId('657975d91935ff9a4d9dc6b0'): {'neg': 0.012, 'neu': 0.879, 'pos': 0.109, 'compound': 0.9884}, ObjectId('657975d91935ff9a4d9dc6b1'): {'neg': 0.091, 'neu': 0.834, 'pos': 0.075, 'compound': 0.6007}, ObjectId('657975d91935ff9a4d9dc6b2'): {'neg': 0.0, 'neu': 0.778, 'pos': 0.222, 'compound': 0.9492}, ObjectId('657975d91935ff9a4d9dc6b3'): {'neg': 0.029, 'neu': 0.893, 'pos': 0.078, 'compound': 0.4019}, ObjectId('657975da1935ff9a4d9dc6b4'): {'neg': 0.0, 'neu': 0.821, 'pos': 0.179, 'compound': 0.8777}, ObjectId('657975da1935ff9a4d9dc6b5'): {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'compound': 0.9495}, ObjectId('657975da1935ff9a4d9dc6b6'): {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.8309}, ObjectId('657975db1935ff9a4d9dc6b7'): {'neg': 0.0, 'neu': 0.851, 'pos': 0.149, 'compound': 0.8625}, ObjectId('657975dc1935ff9a4d9dc6b8'): {'neg': 0.166, 'neu': 0.733, 'pos': 0.101, 'compound': -0.5423}, ObjectId('657975dc1935ff9a4d9dc6b9'): {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.8885}, ObjectId('657975dc1935ff9a4d9dc6ba'): {'neg': 0.09, 'neu': 0.654, 'pos': 0.256, 'compound': 0.836}, ObjectId('657975dd1935ff9a4d9dc6bb'): {'neg': 0.0, 'neu': 0.728, 'pos': 0.272, 'compound': 0.8655}, ObjectId('657975dd1935ff9a4d9dc6bc'): {'neg': 0.122, 'neu': 0.79, 'pos': 0.088, 'compound': -0.25}, ObjectId('657975dd1935ff9a4d9dc6bd'): {'neg': 0.006, 'neu': 0.82, 'pos': 0.173, 'compound': 0.9944}, ObjectId('657975dd1935ff9a4d9dc6be'): {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, ObjectId('657975de1935ff9a4d9dc6bf'): {'neg': 0.121, 'neu': 0.792, 'pos': 0.088, 'compound': -0.2023}, ObjectId('657975de1935ff9a4d9dc6c0'): {'neg': 0.0, 'neu': 0.569, 'pos': 0.431, 'compound': 0.9656}}

# %%
df['Review'] = df['Review'].astype(str) #Converting non string data
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row['Review']
    myid = row['_id']

    # Check if the 'text' variable is a string
    if isinstance(text, str):
        res[myid] = sia.polarity_scores(text)
    else:
        # Handle other data types (e.g., float) as needed
        print(f"Skipping row with non-string data at index {i}")

# Print the results
print(res)
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]
# {ObjectId('657975d51935ff9a4d9dc6ac'): {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, ObjectId('657975d81935ff9a4d9dc6ad'): {'neg': 0.011, 'neu': 0.849, 'pos': 0.14, 'compound': 0.9924}, ObjectId('657975d81935ff9a4d9dc6ae'): {'neg': 0.045, 'neu': 0.804, 'pos': 0.151, 'compound': 0.9526}, ObjectId('657975d81935ff9a4d9dc6af'): {'neg': 0.0, 'neu': 0.851, 'pos': 0.149, 'compound': 0.9854}, ObjectId('657975d91935ff9a4d9dc6b0'): {'neg': 0.012, 'neu': 0.879, 'pos': 0.109, 'compound': 0.9884}, ObjectId('657975d91935ff9a4d9dc6b1'): {'neg': 0.091, 'neu': 0.834, 'pos': 0.075, 'compound': 0.6007}, ObjectId('657975d91935ff9a4d9dc6b2'): {'neg': 0.0, 'neu': 0.778, 'pos': 0.222, 'compound': 0.9492}, ObjectId('657975d91935ff9a4d9dc6b3'): {'neg': 0.029, 'neu': 0.893, 'pos': 0.078, 'compound': 0.4019}, ObjectId('657975da1935ff9a4d9dc6b4'): {'neg': 0.0, 'neu': 0.821, 'pos': 0.179, 'compound': 0.8777}, ObjectId('657975da1935ff9a4d9dc6b5'): {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'compound': 0.9495}, ObjectId('657975da1935ff9a4d9dc6b6'): {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.8309}, ObjectId('657975db1935ff9a4d9dc6b7'): {'neg': 0.0, 'neu': 0.851, 'pos': 0.149, 'compound': 0.8625}, ObjectId('657975dc1935ff9a4d9dc6b8'): {'neg': 0.166, 'neu': 0.733, 'pos': 0.101, 'compound': -0.5423}, ObjectId('657975dc1935ff9a4d9dc6b9'): {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.8885}, ObjectId('657975dc1935ff9a4d9dc6ba'): {'neg': 0.09, 'neu': 0.654, 'pos': 0.256, 'compound': 0.836}, ObjectId('657975dd1935ff9a4d9dc6bb'): {'neg': 0.0, 'neu': 0.728, 'pos': 0.272, 'compound': 0.8655}, ObjectId('657975dd1935ff9a4d9dc6bc'): {'neg': 0.122, 'neu': 0.79, 'pos': 0.088, 'compound': -0.25}, ObjectId('657975dd1935ff9a4d9dc6bd'): {'neg': 0.006, 'neu': 0.82, 'pos': 0.173, 'compound': 0.9944}, ObjectId('657975dd1935ff9a4d9dc6be'): {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, ObjectId('657975de1935ff9a4d9dc6bf'): {'neg': 0.121, 'neu': 0.792, 'pos': 0.088, 'compound': -0.2023}, ObjectId('657975de1935ff9a4d9dc6c0'): {'neg': 0.0, 'neu': 0.569, 'pos': 0.431, 'compound': 0.9656}}

# %%
vaders=pd.DataFrame(res).T
vaders=vaders.reset_index().rename(columns={'index':'_id'})
vaders= vaders.merge(df,how = 'left')

# %%
grouped = vaders.groupby('_id').sum()
data = []

for product_id, row in grouped.iterrows():
    row_total = row['pos'] + row['neu'] + row['neg']
    if row_total > 0:
        positive_percentage = (row['pos'] / row_total) * 100
        neutral_percentage = (row['neu'] / row_total) * 100
        negative_percentage = (row['neg'] / row_total) * 100

        rounded_positive = round(positive_percentage, 1)
        rounded_neutral = round(neutral_percentage, 1)
        rounded_negative = round(negative_percentage, 1)

        data.append({
            "Product ID": product_id,
            "Positive (%)": rounded_positive,
            "Neutral (%)": rounded_neutral,
            "Negative (%)": rounded_negative
        })

# Create a DataFrame from the data
df_table = pd.DataFrame(data)

# Display the table
print(df_table)
# Out:
#                   Product ID  Positive (%)  Neutral (%)  Negative (%)
# 0   657975d51935ff9a4d9dc6ac           0.0        100.0           0.0
# 1   657975d81935ff9a4d9dc6ad          14.0         84.9           1.1
# 2   657975d81935ff9a4d9dc6ae          15.1         80.4           4.5
# 3   657975d81935ff9a4d9dc6af          14.9         85.1           0.0
# 4   657975d91935ff9a4d9dc6b0          10.9         87.9           1.2
# 5   657975d91935ff9a4d9dc6b1           7.5         83.4           9.1
# 6   657975d91935ff9a4d9dc6b2          22.2         77.8           0.0
# 7   657975d91935ff9a4d9dc6b3           7.8         89.3           2.9
# 8   657975da1935ff9a4d9dc6b4          17.9         82.1           0.0
# 9   657975da1935ff9a4d9dc6b5          17.8         82.2           0.0
# 10  657975da1935ff9a4d9dc6b6          17.3         82.7           0.0
# 11  657975db1935ff9a4d9dc6b7          14.9         85.1           0.0
# 12  657975dc1935ff9a4d9dc6b8          10.1         73.3          16.6
# 13  657975dc1935ff9a4d9dc6b9          33.3         66.7           0.0
# 14  657975dc1935ff9a4d9dc6ba          25.6         65.4           9.0
# 15  657975dd1935ff9a4d9dc6bb          27.2         72.8           0.0
# 16  657975dd1935ff9a4d9dc6bc           8.8         79.0          12.2
# 17  657975dd1935ff9a4d9dc6bd          17.3         82.1           0.6
# 18  657975dd1935ff9a4d9dc6be           0.0        100.0           0.0
# 19  657975de1935ff9a4d9dc6bf           8.8         79.1          12.1
# 20  657975de1935ff9a4d9dc6c0          43.1         56.9           0.0
# <ipython-input-55-3af8245cf98e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped = vaders.groupby('_id').sum()

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer= AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]

# %%
#Vaders resultss on example
print(example)
sia.polarity_scores(example)
# Out:
# I am loving this watch, I’m so glad I went with this one and saved the money I would have spent get the EKG included in the series 8 or 9. My cardiologist said it’s not reliable anyways, so I’m glad I asked her first.
# Pros- It is very fast and hasn’t missed a call or notification yet.
# There are tons of features included as well that I love!
# Also, for those people missing the group challenges that Fitbit got rid of, Apple Watches have group challenges 🙌🏼 my whole family was missing those and once I told them the Apple Watches have groups and other fun things like the walkie talkie feature lol, they all ordered one too!!
# Negative- I will say that the battery life on these do not compare to the Fitbit watches. My Sense battery lasted 3 days! This watch barely lasts 24 hours 😭
# And it’s even harder to track my sleep since I end up having to plug it in so it’s ready to go when I wake up.
#
# TLDR- love it so much my whole family ordered them too lol. The battery is disappointing compared to Fitbit. But still worth it!! 4.5 ⭐️
# {'neg': 0.045, 'neu': 0.804, 'pos': 0.151, 'compound': 0.9526}

# %%
# Run for Roberta
encoded_text = tokenizer(example, return_tensors='pt')
output = model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
scores_dict= {
    'roberta_neg' : scores[0],
    'roberta_neu' : scores[1],
    'roberta_pos' : scores[2]
}
print(scores_dict)
# Out:
# {'roberta_neg': 0.022960855, 'roberta_neu': 0.06754822, 'roberta_pos': 0.90949094}

# %%
def polarity_scores_roberta(example) :
  encoded_text = tokenizer(example, return_tensors='pt')
  output = model(**encoded_text)
  scores = output[0][0].detach().numpy()
  scores = softmax(scores)
  scores_dict= {
    'roberta_neg' : scores[0],
    'roberta_neu' : scores[1],
    'roberta_pos' : scores[2]
  }
  return scores_dict

# %%
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]

# %%
df['Review'] = df['Review'].astype(str) #Converting non string data
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row['Review']
    myid = row['_id']

    # Check if the 'text' variable is a string
    if isinstance(text, str):
        res[myid] =  polarity_scores_roberta(text)
    else:
        # Handle other data types (e.g., float) as needed
        print(f"Skipping row with non-string data at index {i}")

# Print the results
print(res)
# Out:
# 100%|██████████| 21/21 [00:13<00:00,  1.59it/s]
# {ObjectId('657975d51935ff9a4d9dc6ac'): {'roberta_neg': 0.23950213, 'roberta_neu': 0.5281889, 'roberta_pos': 0.23230897}, ObjectId('657975d81935ff9a4d9dc6ad'): {'roberta_neg': 0.024123898, 'roberta_neu': 0.21485636, 'roberta_pos': 0.76101977}, ObjectId('657975d81935ff9a4d9dc6ae'): {'roberta_neg': 0.022960855, 'roberta_neu': 0.06754822, 'roberta_pos': 0.90949094}, ObjectId('657975d81935ff9a4d9dc6af'): {'roberta_neg': 0.01549021, 'roberta_neu': 0.11602017, 'roberta_pos': 0.86848956}, ObjectId('657975d91935ff9a4d9dc6b0'): {'roberta_neg': 0.0034537339, 'roberta_neu': 0.041832272, 'roberta_pos': 0.954714}, ObjectId('657975d91935ff9a4d9dc6b1'): {'roberta_neg': 0.24278143, 'roberta_neu': 0.28648102, 'roberta_pos': 0.4707376}, ObjectId('657975d91935ff9a4d9dc6b2'): {'roberta_neg': 0.0026049486, 'roberta_neu': 0.017202502, 'roberta_pos': 0.9801925}, ObjectId('657975d91935ff9a4d9dc6b3'): {'roberta_neg': 0.010448883, 'roberta_neu': 0.055473976, 'roberta_pos': 0.93407714}, ObjectId('657975da1935ff9a4d9dc6b4'): {'roberta_neg': 0.0039916844, 'roberta_neu': 0.048592992, 'roberta_pos': 0.94741535}, ObjectId('657975da1935ff9a4d9dc6b5'): {'roberta_neg': 0.0031268394, 'roberta_neu': 0.016881343, 'roberta_pos': 0.9799918}, ObjectId('657975da1935ff9a4d9dc6b6'): {'roberta_neg': 0.0015162412, 'roberta_neu': 0.0068041272, 'roberta_pos': 0.9916796}, ObjectId('657975db1935ff9a4d9dc6b7'): {'roberta_neg': 0.023295972, 'roberta_neu': 0.14421271, 'roberta_pos': 0.83249134}, ObjectId('657975dc1935ff9a4d9dc6b8'): {'roberta_neg': 0.0028499847, 'roberta_neu': 0.047464833, 'roberta_pos': 0.94968516}, ObjectId('657975dc1935ff9a4d9dc6b9'): {'roberta_neg': 0.0044054915, 'roberta_neu': 0.049907215, 'roberta_pos': 0.94568735}, ObjectId('657975dc1935ff9a4d9dc6ba'): {'roberta_neg': 0.008220489, 'roberta_neu': 0.057363994, 'roberta_pos': 0.9344155}, ObjectId('657975dd1935ff9a4d9dc6bb'): {'roberta_neg': 0.0017679931, 'roberta_neu': 0.009556308, 'roberta_pos': 0.9886757}, ObjectId('657975dd1935ff9a4d9dc6bc'): {'roberta_neg': 0.566382, 'roberta_neu': 0.29553252, 'roberta_pos': 0.1380855}, ObjectId('657975dd1935ff9a4d9dc6bd'): {'roberta_neg': 0.0019019158, 'roberta_neu': 0.028854372, 'roberta_pos': 0.96924376}, ObjectId('657975dd1935ff9a4d9dc6be'): {'roberta_neg': 0.008012457, 'roberta_neu': 0.21521287, 'roberta_pos': 0.7767747}, ObjectId('657975de1935ff9a4d9dc6bf'): {'roberta_neg': 0.19600837, 'roberta_neu': 0.47763577, 'roberta_pos': 0.32635593}, ObjectId('657975de1935ff9a4d9dc6c0'): {'roberta_neg': 0.003387981, 'roberta_neu': 0.012866872, 'roberta_pos': 0.9837451}}

# %%
roberta=pd.DataFrame(res).T
roberta=roberta.reset_index().rename(columns={'index':'_id'})
roberta= roberta.merge(df,how = 'left')

# %%
data = []

for ObjectId, row in grouped.iterrows():
    row_total = row['roberta_pos'] + row['roberta_neu'] + row['roberta_neg']

    if row_total > 0:
        positive_percentage = (row['roberta_pos'] / row_total) * 100
        neutral_percentage = (row['roberta_neu'] / row_total) * 100
        negative_percentage = (row['roberta_neg'] / row_total) * 100

        rounded_positive = round(positive_percentage, 1)
        rounded_neutral = round(neutral_percentage, 1)
        rounded_negative = round(negative_percentage, 1)

        data.append({
            "Product ID": ObjectId,
            "Positive (%)": rounded_positive,
            "Neutral (%)": rounded_neutral,
            "Negative (%)": rounded_negative
        })

# Create a DataFrame from the data
df_table = pd.DataFrame(data)

# Display the table
print(df_table)
# Out:
#                   Product ID  Positive (%)  Neutral (%)  Negative (%)
# 0   657975d51935ff9a4d9dc6ac          23.2         52.8          24.0
# 1   657975d81935ff9a4d9dc6ad          76.1         21.5           2.4
# 2   657975d81935ff9a4d9dc6ae          90.9          6.8           2.3
# 3   657975d81935ff9a4d9dc6af          86.8         11.6           1.5
# 4   657975d91935ff9a4d9dc6b0          95.5          4.2           0.3
# 5   657975d91935ff9a4d9dc6b1          47.1         28.6          24.3
# 6   657975d91935ff9a4d9dc6b2          98.0          1.7           0.3
# 7   657975d91935ff9a4d9dc6b3          93.4          5.5           1.0
# 8   657975da1935ff9a4d9dc6b4          94.7          4.9           0.4
# 9   657975da1935ff9a4d9dc6b5          98.0          1.7           0.3
# 10  657975da1935ff9a4d9dc6b6          99.2          0.7           0.2
# 11  657975db1935ff9a4d9dc6b7          83.2         14.4           2.3
# 12  657975dc1935ff9a4d9dc6b8          95.0          4.7           0.3
# 13  657975dc1935ff9a4d9dc6b9          94.6          5.0           0.4
# 14  657975dc1935ff9a4d9dc6ba          93.4          5.7           0.8
# 15  657975dd1935ff9a4d9dc6bb          98.9          1.0           0.2
# 16  657975dd1935ff9a4d9dc6bc          13.8         29.6          56.6
# 17  657975dd1935ff9a4d9dc6bd          96.9          2.9           0.2
# 18  657975dd1935ff9a4d9dc6be          77.7         21.5           0.8
# 19  657975de1935ff9a4d9dc6bf          32.6         47.8          19.6
# 20  657975de1935ff9a4d9dc6c0          98.4          1.3           0.3

# %%
from transformers import pipeline

# %%
import textwrap

# %%
reviews = df['Review'].tolist()

# Combine all reviews into a single text
combined_text = ' '.join(reviews)

# Wrap the text to limit the length of each sequence
wrapped_text = textwrap.fill(combined_text, width=1020)  # Adjust the width as needed

# Load pre-trained BART model for abstractive summarization
summarizer = pipeline("summarization", model="sshleifer/distilbart-cnn-12-6", revision="a4f8f3e")

# Generate abstractive summary for each sequence
abstractive_summary = []
for chunk in wrapped_text.split('\n'):
    summary_chunk = summarizer(chunk, max_length=150, min_length=50, length_penalty=2.0, num_beams=4, early_stopping=True)
    abstractive_summary.append(summary_chunk[0]['summary_text'])

# Combine the summaries
final_summary = ' '.join(abstractive_summary)

# Print the final abstractive summary
print(final_summary)
# Out:
#  The Apple Watch SE (2nd Generation) [GPS 40mm] with a Silver aluminum Case and Storm Blue Sport Band is a popular option in Apple's smartwatch lineup . The watch excels in health and fitness tracking, offering a variety of features like step counting, step counting and workout tracking .  The Apple Watch SE (2nd Gen) [GPS 40mm] with a Silver Aluminum Case and Storm Blue Sport Band is a balanced mix of features and performance . While it has robust health tracking, it lacks some of the advanced health features found in the more expensive Apple Watch models .  Price, compatibility limitations with non-Apple products, and the absence of some advanced health features are factors to consider . I am loving this watch, I’m so glad I went with this one and saved the money I would have spent get the EKG included in the series 8 or 9 .  The battery is disappointing compared to Fitbit, but still worth it!! I use it to track my activity and steps, but also for notifications . What I really like is the lightweight nature of it . I don’t even feel it on my wrist most of the time, which allows me to sleep with it comfortably .  The Apple Watch SE (2nd Gen) has been a game-changer for a graduate student pursuing a master's in computer science at the University of Florida . With my busy schedule, it's crucial to keep tabs on my physical activity and sleep patterns . One of the standout features for me is the fitness and sleep tracking capabilities .  The watch does an excellent job of tracking steps, calories burned, and encourages me to move when I've been sitting for too long . The sleep tracking feature has been a revelation, providing insights into the quality of my sleep . The watch's ability to detect a potential fall and initiate an emergency call is a reassuring feature .  The Apple Watch SE (2nd Gen) has become an indispensable part of my daily life . Its fitness and health-tracking features, coupled with its integration into my professional and academic activities, make it a must-have for anyone in the IT sector aiming to be a leader in future IT solutions .  The band, selected the loop, is awful. Ugly and so bulky. I haven’t worn a watch in years, so it takes a little getting used to again - and not whacking it on the desk! One gripe. is almost the too high $200 price tag .  The screen quality and resolution is super bright and LED quality . All clock features, fitness tracking, GPS tracking makes it a one in all tool . The battery life is good but you do have to charge it every day if you don’t the battery will only last for 3-4 hours the next day .  Reviewer says it works much smoother and faster than the older models and does exactly what she needs it to do . Bought this watch as a birthday present to replace a much older version . Bought the basic band but you can purchase different style bands .  Apple introduced the Watch SE lineup as a budget-friendly alternative to its premium series . Has great features like if someone elderly falls you can have it contact your listed emergency contact . The features are great. I recommend springing for a newer series .  The most noticeable improvement is its sleeker design . While it retains the iconic Apple Watch look, there's an undeniable modern refinement to it . The updated processor offers quicker responses and smoother command executions . Apps launch with increased speed, and transitions are more fluid, providing a notably enhanced user experience .  In terms of value for money, the Watch SE (2nd Gen) hits the mark given its features and improvements over its predecessor . In conclusion, whether you're contemplating an upgrade from an older model or considering it as a gift for a loved one, it's a stellar choice .

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def cut_text_into_sentences(text, num_sentences=5):
    sentences = nltk.sent_tokenize(text)
    return ' '.join(sentences[:num_sentences])

# Cut the summary to the desired number of sentences
cut_summary = cut_text_into_sentences(final_summary, num_sentences=3)  # Adjust num_sentences as needed

# Print the shortened summary
print(cut_summary)
# Out:
#  The Apple Watch SE (2nd Generation) [GPS 40mm] with a Silver aluminum Case and Storm Blue Sport Band is a popular option in Apple's smartwatch lineup . The watch excels in health and fitness tracking, offering a variety of features like step counting, step counting and workout tracking . The Apple Watch SE (2nd Gen) [GPS 40mm] with a Silver Aluminum Case and Storm Blue Sport Band is a balanced mix of features and performance .
